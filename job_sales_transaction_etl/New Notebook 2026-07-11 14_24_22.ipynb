# %%
# Define job parameters using Databricks widgets for Workflow job_sales_transaction_etl

# Job date parameter (DATE)


dbutils.widgets.text("job_date", "", "Job Date (YYYY-MM-DD)")  

dbutils.widgets.dropdown("environment", "dev", ["dev", "test", "prod"], "Environment")  # Environment parameter (STRING)
dbutils.widgets.text("input_path", "", "Input Path")  # Input path parameter (STRING)
dbutils.widgets.text("output_database", "", "Output Database")  # Output database parameter (STRING)
dbutils.widgets.text("batch_id", "", "Batch ID")  # Batch ID parameter (STRING)

# Retrieve parameter values from widgets
job_date = dbutils.widgets.get("job_date")  # Get job_date value
environment = dbutils.widgets.get("environment")  # Get environment value
input_path = dbutils.widgets.get("input_path")  # Get input_path value
output_database = dbutils.widgets.get("output_database")  # Get output_database value
batch_id = dbutils.widgets.get("batch_id")  # Get batch_id value

# Display retrieved parameters
print("=" * 60)
print("JOB PARAMETERS")
print("=" * 60)
print(f"Job Date:        {job_date}")
print(f"Environment:     {environment}")
print(f"Input Path:      {input_path}")
print(f"Output Database: {output_database}")
print(f"Batch ID:        {batch_id}")
print("=" * 60)
print("\n✓ Parameters loaded successfully")
print("Note: Running on serverless compute - S3 access is automatically configured")
